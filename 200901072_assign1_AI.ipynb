# %% [markdown]
# <h1 style="color:blue"> Muhammad Ahsan Ali</h1>
# <h2 >Reg: 200901072 </h2>

# %%
graph={}
ch = int(input("You want to add graph or automatically generate grap (1=> manually / 2=> automatically):"))
if (ch==2):
    graph = {
    'Arad': [('Zerind', 75), ('Sibiu', 140), ('Timisoara', 118)],
    'Zerind': [('Oradea', 71), ('Arad', 75)],
    'Oradea': [('Zerind', 71), ('Sibiu', 151)],
    'Sibiu': [('Arad', 140), ('Oradea', 151), ('Fagaras', 99), ('Rimnicu Vilcea', 80)],
    'Fagaras': [('Sibiu', 99), ('Bucharest', 211)],
    'Rimnicu Vilcea': [('Sibiu', 80), ('Pitesti', 97), ('Craiova', 146)],
    'Pitesti': [('Rimnicu Vilcea', 97), ('Bucharest', 101), ('Craiova', 138)],
    'Timisoara': [('Arad', 118), ('Lugoj', 111)],
    'Lugoj': [('Timisoara', 111), ('Mehadia', 70)],
    'Mehadia': [('Lugoj', 70), ('Drobeta', 75)],
    'Drobeta': [('Mehadia', 75), ('Craiova', 120)],
    'Craiova': [('Drobeta', 120), ('Rimnicu Vilcea', 146), ('Pitesti', 138)],
    'Bucharest': [('Fagaras', 211), ('Pitesti', 101), ('Giurgiu', 90), ('Urziceni', 85)],
    'Giurgiu': [('Bucharest', 90)],
    'Urziceni': [('Bucharest', 85), ('Hirsova', 98), ('Vaslui', 142)],
    'Hirsova': [('Urziceni', 98), ('Eforie', 86)],
    'Eforie': [('Hirsova', 86)],
    'Vaslui': [('Urziceni', 142), ('Iasi', 92)],
    'Iasi': [('Vaslui', 92), ('Neamt', 87)],
    'Neamt': [('Iasi', 87)]
    }
    print(graph)
else:
    n = int(input("Enter total no of cities:"))
    for x in range(0,(n)):
        name=input("Enter City Name:")
        lisst=[]
        Nb= int(input("Enter total number  of Neighbours :"))
        for x in range(0,(Nb)):
            ctname=input("Enter City Name:")
            wghtt= int(input("Enter weight :"))
            lisst.append((ctname,wghtt))
        print(lisst)
        graph[name]=lisst
    print(graph)
# Out:
# You want to add graph or automatically generate grap (1=> manually / 2=> automatically):2
# ...

# %%
 import networkx as nx
import matplotlib.pyplot as plt
from queue import Queue
class path_Recovery:
    def __init__(self,path,cost):
        self.route = path 
        self.cost=cost

class graphF:
    
    def __init__(self):
        self.frontier = Queue()
        self.frontierDfs = []
        self.explored= []
        
    def BFS(self,start,goal,graph):
        self.explored=[]
        pathS= path_Recovery([start],[0])
        
        self.frontier.put((start,pathS))
        
       # node ,path = self.frontier.get()
       # print(pathS.route)
        
        while not ( self.frontier.empty()):
            node,path = self.frontier.get()
        
           # print("ndoe=>",node,path.route)
            if node == goal:
                print("goal Reachead!")
                print("Path Route:",path.route)
                print("Cost :",path.cost," Total:",sum(path.cost))
                return path.route
            if node  not in self.explored and node != goal:
                #print(node)
                self.explored.append(node)
                for x in range (len(graph[node])):
                        cost = graph[node][x][1]
                        path1 = path_Recovery((path.route + [graph[node][x][0]]),[cost]+path.cost)
                        self.frontier.put((graph[node][x][0] , path1))
   
    def DFS(self,start,goal,graph):
    
        pathS= path_Recovery([start],[0])
        self.explored=[]
        
        self.frontierDfs.append((start,pathS))
        
       # node ,path = self.frontier.get()
        #print(self.frontierDfs[0][1].route)
        
        while len(self.frontierDfs) != 0:
            node,path =  self.frontierDfs.pop()
        
           # print("ndoe=>",node,path.route)
            if node == goal:
                print("goal Reachead!")
                print("Path Route:",path.route)
                print("Cost :",path.cost," Total:",sum(path.cost))
                return path.route
            if node  not in self.explored and node != goal:
                #print(node)
                self.explored.append(node)
                for x in range (len(graph[node])):
                        cost = graph[node][x][1]
                        path1 = path_Recovery((path.route + [graph[node][x][0]]),[cost]+path.cost)
                        self.frontierDfs.append((graph[node][x][0] , path1))            

                
            
                
if __name__ == "__main__":
    
    obj = graphF()
    bfs = obj.BFS("Arad","Bucharest",graph)
    dfs =obj.DFS("Arad","Bucharest",graph)
    print("BFS has out-perfomed the DFS")
# Out:
# goal Reachead!
# Path Route: ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']
# Cost : [211, 99, 140, 0]  Total: 450
# goal Reachead!
# Path Route: ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# Cost : [101, 138, 120, 75, 70, 111, 118, 0]  Total: 733
# BFS has out-perfomed the DFS

# %%
cityNames = list(graph.keys())
G=nx.Graph()
for x in cityNames:
    G.add_node(x)
lbl = {}
cl=[]
i=0
for x in cityNames:
    for y in  range(len(graph[x])):
    
            G.add_edge(x , graph[x][y][0], weight= graph[x][y][1])
                          


        
#pos = nx.layout.kamada_kawai_layout(G)

# %%
print("BFS: ",bfs)
pos = nx.spring_layout(G)
fig, ax = plt.subplots(figsize=(15, 15))
colors =['b', 'r', 'b', 'b', 'b', 'r', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b',
         'b', 'b', 'b', 'b', 'b', 'b']

nx.draw(G , edge_color=colors, with_labels=True  ,node_size=100 ,ax=ax )   
plt.show()
# Out:
# BFS:  ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']

# %%
print("DFS:",dfs)     
pos = nx.spring_layout(G)
fig, ax = plt.subplots(figsize=(15, 15))
colors =['b', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'r', 'r', 'r', 'r', 'r', 'r', 'b',
         'b', 'b', 'b', 'b', 'b', 'b']
nx.draw(G , edge_color=colors, with_labels=True   ,node_size=100 ,ax=ax )   
plt.show()
# Out:
# DFS: ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
